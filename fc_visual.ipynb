# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. preprocessed data
# 2. run tvb-FC compute
# 3. visual the results

# %%
df = pd.read_csv("/home/yat-lok/workspace/S122817_output/fMRI/rfMRI.ica/fc.txt", sep=" ", header=None)
fig = plt.figure(figsize=(12,10))
axes = fig.add_subplot(111)
sns.heatmap(df)
plt.show()
